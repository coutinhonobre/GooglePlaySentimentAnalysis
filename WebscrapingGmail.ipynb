# %%
# !pip3 install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in ./.venv/lib/python3.9/site-packages (1.2.4)

# %%
import csv

# %%
def create_csv(name_file):
    new_name_file = name_file.replace('.', '_') + '.csv'
    with open(new_name_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Review', 'Username', 'Rating', 'AppName'])
    print('CSV file created successfully.')

# %%
def insert_values(name_file, review, username, rating):
    new_name_file = name_file.replace('.', '_') + '.csv'
    with open(new_name_file, 'a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([review, username, rating, name_file])
    print('Value inserted successfully.')

# %%
def search_reviews(app_name):
    from google_play_scraper import app, Sort, reviews_all

    # ID do aplicativo no Google Play Store
    app_id = app_name

    # Recuperar informações do aplicativo
    gmail_app_info = app(app_id)
    create_csv(app_name)

    # Exibir informações básicas do aplicativo
    print(f"App Title: {gmail_app_info['title']}")
    print(f"Developer: {gmail_app_info['developer']}")
    print(f"Rating: {gmail_app_info['score']}")

    # Obter todas as avaliações do aplicativo
    gmail_reviews = reviews_all(
        app_id,
        sleep_milliseconds=0,  # Pausa entre solicitações (recomendado)
        lang="en",  # Idioma das avaliações
        country="us",  # País das avaliações
        sort=Sort.MOST_RELEVANT,  # Ordem de classificação das avaliações
    )

    # Exibir as avaliações
    for i, review in enumerate(gmail_reviews):
        print(f"Review {i + 1}:")
        print(f"  Username: {review['userName']}")
        print(f"  Rating: {review['score']}")
        print(f"  Review: {review['content']}")
        print("------")
        insert_values(app_name, review['content'], review['userName'], review['score'])

# %%
apps = [
    'br.com.renanrodrigues.ifgmobile',
    'br.gov.meugovbr',
    'br.gov.dataprev.meuinss'
]
apps
# Out:
# ['br.com.renanrodrigues.ifgmobile',
#  'br.gov.meugovbr',
#  'br.gov.dataprev.meuinss']

# %%
for app in apps:
    search_reviews(app)
# Out:
# CSV file created successfully.
# App Title: IFG Mobile
# Developer: Serviços e Informações do Brasil
# Rating: 0
# Review 1:
#   Username: A Google user
#   Rating: 4
#   Review: A porcentagem de faltas está em desacordo com as faltas do acadêmico pelo
# site.
# ------
# Value inserted successfully.
# Review 2:
#   Username: A Google user
#   Rating: 4
#   Review: Teria como mandar uma notificação  quando houver  alteração  de nota?
# ------
# Value inserted successfully.
# Review 3:
#   Username: A Google user
#   Rating: 5
#   Review: Parabéns à equipe da PROEN/IFG
# ------
# Value inserted successfully.
# CSV file created successfully.
# App Title: gov.br
# Developer: Serviços e Informações do Brasil
# Rating: 4.6685796
# Review 1:
#   Username: Carlos Rabelo
#   Rating: 1
#   Review: Horrível. Reconhecimento facial não funciona. Horrible. Facial recognition doesn't work.
# ------
# Value inserted successfully.
# Review 2:
#   Username: saudade imoveis
#   Rating: 1
#   Review: Terrible. Facial reckon doesnt work.
# ------
# Value inserted successfully.
# Review 3:
#   Username: Carlos Daniel Villalba Zaracho
#   Rating: 5
#   Review: Easy to use and really useful.
# ------
# Value inserted successfully.
# Review 4:
#   Username: Erico Oliveira
#   Rating: 5
#   Review: its interesting form of facial recognizing
# ------
# Value inserted successfully.
# Review 5:
#   Username: Thomas Zink Koelle
#   Rating: 5
#   Review: Super easy to use app that helps with documentation in Brazil!!!!!
# ------
# Value inserted successfully.
# Review 6:
#   Username: rodrigo santos
#   Rating: 4
#   Review: Process fast enough and easy.
# ------
# Value inserted successfully.
# Review 7:
#   Username: Paulo Canuto
#   Rating: 5
#   Review: Light, fluid and intuitive application. It fulfills satisfactorily its basic functionalities.
# ------
# Value inserted successfully.
# Review 8:
#   Username: Cau Trindade
#   Rating: 1
#   Review: Can't install in my Samsung S21 Ultra. It starts downloading but always show an error when trying to install.
# ------
# Value inserted successfully.
# Review 9:
#   Username: Eduardo Oliveira
#   Rating: 1
#   Review: The service does not work. Everything keeps motionless, so we can't conclude the process.
# ------
# Value inserted successfully.
# Review 10:
#   Username: Linw Marx
#   Rating: 1
#   Review: Requires too many private information, photos. It's making me uncomfortable.
# ------
# Value inserted successfully.
# Review 11:
#   Username: Adriel Martins
#   Rating: 5
#   Review: Great service!! Fast and secure. All digital. Just great!
# ------
# Value inserted successfully.
# Review 12:
#   Username: Juliana Fajardini
#   Rating: 1
#   Review: Wants access to sensible info but I distrust this government and its ability to protect or use my data wisely
# ------
# Value inserted successfully.
# Review 13:
#   Username: Haryel Freire
#   Rating: 1
#   Review: Nada funciona nessa bomba. Dá erro logo quando abre. Attempt to invoke virtual method java.security.publickey on a null reference object.
# ------
# Value inserted successfully.
# Review 14:
#   Username: Ana Cláudia Madeira
#   Rating: 1
#   Review: O app não acessa. Está dando erro de Java. "publicKey on a null object reference" Android 11 - XIAOMI Redmi 9 pro MIUI 12.5.3
# ------
# Value inserted successfully.
# Review 15:
#   Username: Elaine Sajonia
#   Rating: 5
#   Review: it's great because it will help a lot of people who are seeking for help about our situation here in Brasil
# ------
# Value inserted successfully.
# Review 16:
#   Username: Julio Brenicci
#   Rating: 5
#   Review: Great App, helped me too. 👏
# ------
# Value inserted successfully.
# Review 17:
#   Username: Antonio Braganca Martins
#   Rating: 1
#   Review: Era ótimo! No Android 11 não abre! Samsung A22
# ------
# Value inserted successfully.
# Review 18:
#   Username: Felipe Yazbek
#   Rating: 1
#   Review: App crashing all the time!
# ------
# Value inserted successfully.
# Review 19:
#   Username: Muss Mestre
#   Rating: 3
#   Review: Lot's of steps
# ------
# Value inserted successfully.
# Review 20:
#   Username: Wanderson
#   Rating: 4
#   Review: This is proof that the state, when well managed, by an efficient bureaucracy, can be more efficient than the private initiative.
# ------
# Value inserted successfully.
# Review 21:
#   Username: Leon Unger
#   Rating: 5
#   Review: eh mutton bomb memo. uso sempre
# ------
# Value inserted successfully.
# Review 22:
#   Username: Perla Berkowitz
#   Rating: 3
#   Review: it took a long time, but it worked!
# ------
# Value inserted successfully.
# Review 23:
#   Username: Loriedson Emma-O
#   Rating: 5
#   Review: show kkkkk, maneiro kkkk
# ------
# Value inserted successfully.
# Review 24:
#   Username: Junior Brandão
#   Rating: 1
#   Review: Erro ao concluir cadastro "Internal HTTP Server Error"
# ------
# Value inserted successfully.
# Review 25:
#   Username: Wilmi Pwa
#   Rating: 1
#   Review: Não funciona no Android 11 (Xiaomi MIUI 12.5.5)
# ------
# Value inserted successfully.
# Review 26:
#   Username: Everton JS
#   Rating: 4
#   Review: Did't open this App. Excuse-me , uninstall.
# ------
# Value inserted successfully.
# Review 27:
#   Username: Geraldo Cardoso
#   Rating: 1
#   Review: Bad very bad, crappie, fishing,experience,
# ------
# Value inserted successfully.
# Review 28:
#   Username: Luiz Oliveira
#   Rating: 5
#   Review: very easy and fast
# ------
# Value inserted successfully.
# Review 29:
#   Username: Henri Bigatti
#   Rating: 5
#   Review: Very good APP, congratulations.
# ------
# Value inserted successfully.
# Review 30:
#   Username: Farwaz Sulley
#   Rating: 3
#   Review: How can I create an account or how can get the CPF?
# ------
# Value inserted successfully.
# Review 31:
#   Username: Rafa Silver (Josie)
#   Rating: 1
#   Review: nao consigo logar (Android 9)
# ------
# Value inserted successfully.
# Review 32:
#   Username: Teacher Leo
#   Rating: 1
#   Review: Can't even conclude the installation process. This app should not be available for download.
# ------
# Value inserted successfully.
# Review 33:
#   Username: luiz Ferreira
#   Rating: 5
#   Review: fast and pratic
# ------
# Value inserted successfully.
# Review 34:
#   Username: Caçarola Napolitano
#   Rating: 1
#   Review: Não funciona no android 7.
# ------
# Value inserted successfully.
# Review 35:
#   Username: Funny The Channel it's so amazing
#   Rating: 5
#   Review: Maybe be good but it is sowing troubles on my phone
# ------
# Value inserted successfully.
# Review 36:
#   Username: Elcio Cadene
#   Rating: 1
#   Review: Nāo funciona no Android 11.
# ------
# Value inserted successfully.
# Review 37:
#   Username: Ed Correa
#   Rating: 1
#   Review: Poor, now why is a brazilian gov.br needs to be evaluated in English?
# ------
# Value inserted successfully.
# Review 38:
#   Username: Fox Ushiha
#   Rating: 5
#   Review: muito útil (Very useful)
# ------
# Value inserted successfully.
# Review 39:
#   Username: Lawrence D'Mello
#   Rating: 1
#   Review: Não consigo abrir no Samsung A31
# ------
# Value inserted successfully.
# Review 40:
#   Username: Myriel Pádua
#   Rating: 5
#   Review: it Looks handful!!
# ------
# Value inserted successfully.
# Review 41:
#   Username: Henrique Rodrigues
#   Rating: 5
#   Review: good and fast!
# ------
# Value inserted successfully.
# Review 42:
#   Username: SACRATUS ARKHANGELOS MICHAELIS MICHAELIS
#   Rating: 3
#   Review: It's Brazil, did you expect caviar and expensive wines? You were fooled, unless you are a politician, lawyer or judge.
# ------
# Value inserted successfully.
# Review 43:
#   Username: mary delfino
#   Rating: 5
#   Review: fast works well
# ------
# Value inserted successfully.
# Review 44:
#   Username: W Daniel
#   Rating: 5
#   Review: it Worked Perfectly.
# ------
# Value inserted successfully.
# Review 45:
#   Username: Wesley Jr.
#   Rating: 1
#   Review: I don't have CNH! How can I access my account??
# ------
# Value inserted successfully.
# Review 46:
#   Username: Pablo sx
#   Rating: 1
#   Review: Bad face recognition
# ------
# Value inserted successfully.
# Review 47:
#   Username: Patrícia Schappo
#   Rating: 1
#   Review: O App não funciona
# ------
# Value inserted successfully.
# Review 48:
#   Username: Bear maker
#   Rating: 1
#   Review: Goes around and around
# ------
# Value inserted successfully.
# Review 49:
#   Username: Karina Pinheiro
#   Rating: 5
#   Review: eu amo esse app!!
# ------
# Value inserted successfully.
# Review 50:
#   Username: Tuco Santana
#   Rating: 5
#   Review: First use ok. let's see how it goes.
# ------
# Value inserted successfully.
# Review 51:
#   Username: Matheus Turella
#   Rating: 5
#   Review: thanks again for your email address
# ------
# Value inserted successfully.
# Review 52:
#   Username: Eula Paula
#   Rating: 5
#   Review: It's wonderful
# ------
# Value inserted successfully.
# Review 53:
#   Username: IN GOD WE TRUST MaybeLLine-inc 1776
#   Rating: 3
#   Review: IN GOD WE TRUST Bolsonaro 2022 Trump Version Made in Brazil 🇧🇷 MAGA Make Britain 🇬🇧 Great Again 🇬🇧 META. Make Everything Trump Again Trump 2024
# ------
# Value inserted successfully.
# Review 54:
#   Username: Van Glauco
#   Rating: 5
#   Review: show esse app
# ------
# Value inserted successfully.
# Review 55:
#   Username: Hilton Bros Dellaware (IN GOD WE TRUST)
#   Rating: 4
#   Review: IN GOD WE TRUST.. Bolsonaro 2022 TRUMP 2024
# ------
# Value inserted successfully.
# Review 56:
#   Username: Víctor Martínez
#   Rating: 5
#   Review: Excelente aplicativo, funciona de maravilha!
# ------
# Value inserted successfully.
# Review 57:
#   Username: Marcos Sanches
#   Rating: 1
#   Review: Ele desabilita a biometria depois de um tempo
# ------
# Value inserted successfully.
# Review 58:
#   Username: Luciano Silva
#   Rating: 5
#   Review: excelente aplicativo, recomendo!
# ------
# Value inserted successfully.
# Review 59:
#   Username: Gustavo Henrique Cunha da Rosa
#   Rating: 1
#   Review: Nada funciona, como de praxe no brasil
# ------
# Value inserted successfully.
# Review 60:
#   Username: O Ceifador
#   Rating: 3
#   Review: Falta segurança para com nossos dados e informações pessoais.
# ------
# Value inserted successfully.
# Review 61:
#   Username: Leonardo
#   Rating: 5
#   Review: good
# ------
# Value inserted successfully.
# Review 62:
#   Username: Marco Lampert
#   Rating: 1
#   Review: não funcionou a biometria facial
# ------
# Value inserted successfully.
# Review 63:
#   Username: Marilza Helena Perei
#   Rating: 5
#   Review: Grata
# ------
# Value inserted successfully.
# Review 64:
#   Username: Rúbea Centenaro
#   Rating: 1
#   Review: Depois de realizar o cadastro e fazer reconhecimento facial, o aplicativo simplesmente não permite o meu acesso alegando "Biometria facial não encontrada". Legal, agora que realizei meu cadastro, não posso acessá-lo e nem sei como cancelar. Simplesmente um lixo.
# ------
# Value inserted successfully.
# Review 65:
#   Username: educostinha
#   Rating: 3
#   Review: seis meses depois, consegui o reconhecimento facial.
# ------
# Value inserted successfully.
# Review 66:
#   Username: D. Alves (D. Alv)
#   Rating: 1
#   Review: Pouco confiável, reconhecimento facial falha, bloqueando App
# ------
# Value inserted successfully.
# Review 67:
#   Username: Gustavo
#   Rating: 1
#   Review: Lixo, não me deixa conectar
# ------
# Value inserted successfully.
# Review 68:
#   Username: lucky 748
#   Rating: 1
#   Review: Reconhecimento Facil Faz parte da agenda de controle Absoluto Chines.
# ------
# Value inserted successfully.
# Review 69:
#   Username: Adriano Sant'Ana
#   Rating: 5
#   Review: foi rápido e pareceu eficiente
# ------
# Value inserted successfully.
# Review 70:
#   Username: Regis Silva
#   Rating: 5
#   Review: Agora está fácil recuperar a senha por reconhecimento facial.
# ------
# Value inserted successfully.
# Review 71:
#   Username: Júlia Ana Vieira
#   Rating: 5
#   Review: Aplicativo maravilhoso e que simplifica muitíssimo a vida da gente.
# ------
# Value inserted successfully.
# Review 72:
#   Username: Diego Vintem
#   Rating: 4
#   Review: Good, thanks!
# ------
# Value inserted successfully.
# Review 73:
#   Username: Danilo Guimarães Dantas
#   Rating: 2
#   Review: nao adaptado para tablet na horizontal
# ------
# Value inserted successfully.
# Review 74:
#   Username: Roberto Brela
#   Rating: 1
#   Review: terrible app
# ------
# Value inserted successfully.
# Review 75:
#   Username: Paula Damasia
#   Rating: 1
#   Review: Mais uma vez estou tentando entrar no app e não consigo. Da erro se tento entrar com o banco e com biometria facial.
# ------
# Value inserted successfully.
# Review 76:
#   Username: Waldimir Sousa
#   Rating: 5
#   Review: Cool
# ------
# Value inserted successfully.
# Review 77:
#   Username: DJ MAUROLUCIO
#   Rating: 5
#   Review: nice
# ------
# Value inserted successfully.
# Review 78:
#   Username: Eduardo Torres
#   Rating: 1
#   Review: Sem acesso a minha conta
# ------
# Value inserted successfully.
# Review 79:
#   Username: Wesley Smitthe
#   Rating: 1
#   Review: Estou a dias tentando fazer o reconhecimento facial e não funciona, o app não possuo nenhum ponto de atendimento para que você ser auxiliado, preciso fazer meu imposto de renda e não importa o que eu faça o app não funciona.
# ------
# Value inserted successfully.
# Review 80:
#   Username: Alais Fuzaro
#   Rating: 2
#   Review: Ao selecionar a opção de dupla verificação offline, o App dá erro na leitura do QR code, dizendo que o QR code gerado (pelo site Gov) é incompatível com o App.
# ------
# Value inserted successfully.
# Review 81:
#   Username: Renata Guerra
#   Rating: 5
#   Review: muito bom
# ------
# Value inserted successfully.
# Review 82:
#   Username: Gus V
#   Rating: 1
#   Review: tudo ladrão
# ------
# Value inserted successfully.
# Review 83:
#   Username: Marco Antonio
#   Rating: 5
#   Review: excelente!
# ------
# Value inserted successfully.
# Review 84:
#   Username: Juliane Ferrareto
#   Rating: 5
#   Review: Assertivo.
# ------
# Value inserted successfully.
# Review 85:
#   Username: Flavio Jarabeck
#   Rating: 5
#   Review: funciona.
# ------
# Value inserted successfully.
# Review 86:
#   Username: Pedro Cavalcante
#   Rating: 5
#   Review: tudo
# ------
# Value inserted successfully.
# Review 87:
#   Username: Jalles Gomes Rosa
#   Rating: 5
#   Review: Sensacional
# ------
# Value inserted successfully.
# Review 88:
#   Username: suksuk CDs o moral da região suksuk CDs
#   Rating: 5
#   Review: facil
# ------
# Value inserted successfully.
# Review 89:
#   Username: daniel santiago
#   Rating: 5
#   Review: legal
# ------
# Value inserted successfully.
# Review 90:
#   Username: Lana Ladeia
#   Rating: 5
#   Review: otimo
# ------
# Value inserted successfully.
# Review 91:
#   Username: Jonatan Cesar emboaba Emboaba
#   Rating: 5
#   Review: bom
# ------
# Value inserted successfully.
# Review 92:
#   Username: Davis Lima
#   Rating: 5
#   Review: otimo
# ------
# Value inserted successfully.
# Review 93:
#   Username: Breno Queiroga
#   Rating: 1
#   Review: horrível
# ------
# Value inserted successfully.
# Review 94:
#   Username: Mad Old Man Yelling
#   Rating: 1
#   Review: Aplicativo horrível! Eu preciso entrar no INSS para baixar o demonstrativo de renda para o imposto de renda deste ano. O aplicativo não deixa entrar em nada, não deixa entrar em qualquer coisa sem antes fazer o reconhecimento facial. Mas o aplicativo não consegue fazer o reconhecimento facial de jeito nenhum, não importa qual a posição, a distância do rosto ou a iluminação, ele simplesmente não faz o reconhecimento facial!!! E agora, como é que fica se o usuário não consegue usar mais o app?!
# ------
# Value inserted successfully.
# Review 95:
#   Username: Sophia Giz
#   Rating: 1
#   Review: valeu por aumentarem a contribuição de impostos, valeu por contribuírem pro meu emagrecimento, valeu por fazerem eu comer as vezes menos de 2 refeições por dia, valeu por usarem o dinheiro desses impostos em qualquer outra coisa menos no melhoramento desses aplicativos inúteis, valeu por fazerem eu amar esse país cada vez mais. espero que o Brasil quebre pois é isso que merecem, tenho vergonha de ter nascido aqui, muito obrigada mesmo
# ------
# Value inserted successfully.
# Review 96:
#   Username: Hans Zimmer
#   Rating: 1
#   Review: As vezes aparecem dez captchas para entrar. O sujeito que colocou senha E CAPTCHAS, deveria ser despedido. Só tem cpf e cnh. Faltam ci, titulo, etc,etc,etc. 2023-03-14. O que deveria ser um sistema de alta disponibilidade, esta fora do ar, não autentica, erro 403 em alguns casos. Serpro sempre fazendo m para variar. 2023-05-02. Aplicativo não funciona mais. Entra em loop na autenticação, pergunta se quer autenticar por senha ou pelo app (sic).
# ------
# Value inserted successfully.
# Review 97:
#   Username: * smoldah
#   Rating: 1
#   Review: horrível o reconhecimento facial.. necessário implementar outros meios de verificação..
# ------
# Value inserted successfully.
# Review 98:
#   Username: Paula Konrath Fleck
#   Rating: 3
#   Review: demora mto pra reconhecer o rosto
# ------
# Value inserted successfully.
# Review 99:
#   Username: Ismaell Pereira
#   Rating: 5
#   Review: 😉👍🆗
# ------
# Value inserted successfully.
# Review 100:
#   Username: Dartanhan Carvalho
#   Rating: 1
#   Review: Nao funciona. Eu estou preso em um loop em que eu não posso aumentar o nível porque eu preciso usar o QR code, mas eu não posso usar o QR code porque eu o aplicativo me manda fazer login pelo browser, e não pelo app. Eu só uso Nubank e ele não está listado cono opção de aumentar o nível da conta.
# ------
# Value inserted successfully.
# Review 101:
#   Username: Wolfgang
#   Rating: 1
#   Review: Terrível, péssimo, irritante, frustrante. Um mês pra tirar uma simples carteira de trabalho. Sem falar nas infinitas informações pessoais exigidas. Só faltou perguntar onde eu moro, que horas que eu acordo, com que frequência vou ao banheiro e etc. Enfim, o governo realmente quer seus gados sob controle total.
# ------
# Value inserted successfully.
# Review 102:
#   Username: Frantchesco
#   Rating: 2
#   Review: se voce desinstala. nunca mais consegue logar.
# ------
# Value inserted successfully.
# Review 103:
#   Username: Ramon Las-Cazas
#   Rating: 2
#   Review: muito bom, nota 2
# ------
# Value inserted successfully.
# Review 104:
#   Username: marsch
#   Rating: 1
#   Review: Aplicativo inutil, reconhecimento facil bugado e nao funciona, nao loga e portanto fica com zero utilidade. Fora as evidentes falhas na programacao da interface de usuario.
# ------
# Value inserted successfully.
# Review 105:
#   Username: Vitoria Azevedo
#   Rating: 5
#   Review: me estressa
# ------
# Value inserted successfully.
# Review 106:
#   Username: Elves
#   Rating: 4
#   Review: Muito bom
# ------
# Value inserted successfully.
# Review 107:
#   Username: Manoel Leal
#   Rating: 1
#   Review: Está dando erro no reconhecimento facial durante o login e o app não dá nenhuma outra alternativa para a realizaçao de login a não ser por esse reconhecimento. Estou a vários dias sem conseguir acessar no app.
# ------
# Value inserted successfully.
# Review 108:
#   Username: Bernardo Rufino
#   Rating: 3
#   Review: Funciona razoavelmente bem. Algo que poderia ter é acesso a serviços como o PROCON, fazendo uma reclamação oficial etc, tipo como é fazer um B.O. online hoje em outros órgãos.
# ------
# Value inserted successfully.
# Review 109:
#   Username: Cleber de Souza Bezerra
#   Rating: 1
#   Review: Péssimo.
# ------
# Value inserted successfully.
# Review 110:
#   Username: Larissa Gonçalves Munhós
#   Rating: 1
#   Review: Eu não lembro a minha senha. O aplicativo manda eu fazer o login através do navegador. Quando clico em esqueci minha senha ele manda eu baixar o aplicativo para fazer reconhecimento facial. Estou perdida num ciclo onde não existe solução
# ------
# Value inserted successfully.
# Review 111:
#   Username: name Name
#   Rating: 5
#   Review: bom
# ------
# Value inserted successfully.
# Review 112:
#   Username: Matheus Cândido Teixeira
#   Rating: 5
#   Review: ok
# ------
# Value inserted successfully.
# Review 113:
#   Username: Eduardo Tenório
#   Rating: 5
#   Review: essencial
# ------
# Value inserted successfully.
# Review 114:
#   Username: Marcelo Paludo Wille
#   Rating: 1
#   Review: Lixo
# ------
# Value inserted successfully.
# Review 115:
#   Username: A Google user
#   Rating: 1
#   Review: Este app foi claramente desenvolvido para não funcionar. Ele já vem com uma senha cadastrada... Se vc tenta recuperar a senha, o email cadastrado não é meu, o reconhecimento facial não funciona, e as contas bancárias não reconhecem minha senha. Resumindo... É inútil.
# ------
# Value inserted successfully.
# Review 116:
#   Username: Rodrigo F.
#   Rating: 2
#   Review: Instalei para tentar aumentar meu nível para Ouro, mas o app mostra a mensagem que "não será possível fazer o reconhecimento facial", me impossibilitando de aumentar meu nível. Aumentar para o nível Prata não é uma opção para mim pois não tenho conta em nenhum banco da lista.
# ------
# Value inserted successfully.
# Review 117:
#   Username: Djalma Junior
#   Rating: 1
#   Review: Depois de muitas tentativas eu resolvi mudar minha avaliação. O aplicativo simplesmente não funciona. estou a meses tentando aumentar o nível de segurança mas o reconhecimento facila não funciona e a opção de ler o QRcode da carteira de motorista simplesmente não aparece. Aplicativo limitado e nada intuitivo.
# ------
# Value inserted successfully.
# Review 118:
#   Username: PHDBR2
#   Rating: 2
#   Review: além de sempre dar problema na hora de login e abrir 5 abas no browser pedindo reconhecimento facial (que eu não habilitei) ainda é lento e muitas vezes não faz o que as instruções dizem. Ou pior, simplesmente dá erro na hora de solicitar informações e pede pra tentar de novo mais tarde.
# ------
# Value inserted successfully.
# Review 119:
#   Username: Fernando Romero
#   Rating: 1
#   Review: lixoooo, tive que fazer umas 20 tentativas antes de reconhecer minha face. Depois fui usar pra autenticar no e-cac para poder fazer o imposto de renda e dá erro 403. Muito ruim os serviços do governo. Pra cobrar imposto é bom , mas pra fazer um serviço decente pra população é muito ruim.
# ------
# Value inserted successfully.
# Review 120:
#   Username: Marcos Paulo Gonçalves
#   Rating: 5
#   Review: desmascara intruso de conta com numero de outro chip com acesso ao gmail suspeito que desviam dinheiro do bolsa familia pelo facebook inativo posso estar enganado meu windows 8 esta funcionando em outro computador moro na humaita 217 fundos apto 3 Terreo Taubaté SP apareceu cnpj no meu cpf fui notificado compareci no sebrae pra desativar depois disso apareceu outro cnpj o primeiro com uma divida de 1200，00 o outro com uma divida recente de 90,00 consegui recuperar esse gmail ele é o primeiro .
# ------
# Value inserted successfully.
# Review 121:
#   Username: alessandra bandeira
#   Rating: 5
#   Review: É ótimo para tudo! Gostei desta pegada high tech governamental. Fica bem melhor obter tudo que é necessário quando o assunto é documentação de benefícios.🤭
# ------
# Value inserted successfully.
# Review 122:
#   Username: Conexao com Cristo
#   Rating: 1
#   Review: uma idiotice muito mal feita, vc perde mais tempo pra este sistema idiota fazer o reconhecimento facial do que pesquisando o uqe vc precisa
# ------
# Value inserted successfully.
# Review 123:
#   Username: Vinícius Gobbo Antunes de Oliveira
#   Rating: 1
#   Review: Mais um aplicativo lento, desnecessário, inútil.
# ------
# Value inserted successfully.
# Review 124:
#   Username: Marcos Pereira dos Santos
#   Rating: 1
#   Review: 20 minutos pra fazer login
# ------
# Value inserted successfully.
# Review 125:
#   Username: Alex Santee
#   Rating: 1
#   Review: Reconhecimento facial simplesmente não funciona. Ele não abre a câmera e mostra um erro nada descritivo
# ------
# Value inserted successfully.
# Review 126:
#   Username: big b0ss
#   Rating: 1
#   Review: Aplicativo horrível. Invasivo, cheio de bug, nada funciona, feijoada.
# ------
# Value inserted successfully.
# Review 127:
#   Username: Leandro Henrique
#   Rating: 2
#   Review: Reconhecimento facial sempre dá erro... não consigo usar o app
# ------
# Value inserted successfully.
# Review 128:
#   Username: Lucah Moreira
#   Rating: 5
#   Review: facilita muito na navegação pra saber sobre informações de documentos pessoais!!!
# ------
# Value inserted successfully.
# Review 129:
#   Username: Fernando Assad
#   Rating: 5
#   Review: Sistema Fantástico, mais avançado do que qualquer sistema de outros países
# ------
# Value inserted successfully.
# Review 130:
#   Username: Minawadrash
#   Rating: 1
#   Review: É do governo, é ruim
# ------
# Value inserted successfully.
# Review 131:
#   Username: Andre Athar
#   Rating: 5
#   Review: great! só precisa melhorar o reconhecimento facial
# ------
# Value inserted successfully.
# Review 132:
#   Username: Silvio Rebelo
#   Rating: 1
#   Review: Instalei e não consegui acessar. Aparece 403 forbidden.
# ------
# Value inserted successfully.
# Review 133:
#   Username: Felipe Amorim
#   Rating: 1
#   Review: Como esperado, um lixo.
# ------
# Value inserted successfully.
# Review 134:
#   Username: Laura Dusi
#   Rating: 1
#   Review: Reconhecimento facial não funciona pra entrar no app
# ------
# Value inserted successfully.
# Review 135:
#   Username: natanael quintino
#   Rating: 5
#   Review: Problema com login via soo resolvido!
# ------
# Value inserted successfully.
# Review 136:
#   Username: Ramon Barrio
#   Rating: 1
#   Review: As funcionalidade de leitura de QR Code e Reconhecimento Facial não funcionam
# ------
# Value inserted successfully.
# Review 137:
#   Username: ユリキ
#   Rating: 1
#   Review: servico horrivel, reconhecimento facial bloqueia por 24 horas apos falhar apenas 2 vezes.
# ------
# Value inserted successfully.
# Review 138:
#   Username: Thiarles Silva
#   Rating: 1
#   Review: Se for usuario bronze não serve pra nada, é obrigatório cadastrar algum outro tipo de dados
# ------
# Value inserted successfully.
# Review 139:
#   Username: Gabrielle Bueno
#   Rating: 1
#   Review: Não consigo acessar minha conta, app péssimo
# ------
# Value inserted successfully.
# Review 140:
#   Username: Jocelio Candido
#   Rating: 5
#   Review: Excelente forma de controle e atualização de informações.
# ------
# Value inserted successfully.
# Review 141:
#   Username: LUIX
#   Rating: 1
#   Review: Atendimento horrível, péssimo, mentiroso.
# ------
# Value inserted successfully.
# Review 142:
#   Username: Moacyr Rocha
#   Rating: 1
#   Review: Reconhecimento facial dificílimo de funcionar.
# ------
# Value inserted successfully.
# Review 143:
#   Username: EXTERMINADOR FODEX
#   Rating: 1
#   Review: faz parte do sistema do governo global, do império do anticristo
# ------
# Value inserted successfully.
# Review 144:
#   Username: Alberto Nordmann Garagorry
#   Rating: 1
#   Review: O app não instala e não fala porque
# ------
# Value inserted successfully.
# Review 145:
#   Username: Carlos Daniel
#   Rating: 1
#   Review: O reconhecimento facial não está funcionando
# ------
# Value inserted successfully.
# Review 146:
#   Username: Chiquinho Lemos
#   Rating: 1
#   Review: Estou orecisando fazer o CMC baixei o aplicatico mas nao consigo fazer o cadastro... Me pede o cpf e depois senha mas como terei senha se nao consigo fazer o cadastro!
# ------
# Value inserted successfully.
# Review 147:
#   Username: Gilberto Maia
#   Rating: 5
#   Review: Agilidade, eficiência e transparência. Usar a tecnologia para melhorar a prestação de serviço e reduzir a estrutura pesada do funcionalismo público.
# ------
# Value inserted successfully.
# Review 148:
#   Username: Anabela Silva
#   Rating: 5
#   Review: interesting 🤔
# ------
# Value inserted successfully.
# Review 149:
#   Username: Eduardo Bender
#   Rating: 1
#   Review: Reconhecimento Facial não funciona
# ------
# Value inserted successfully.
# Review 150:
#   Username: Massaru Fukuda
#   Rating: 5
#   Review: excellent
# ------
# Value inserted successfully.
# Review 151:
#   Username: cesar kimura
#   Rating: 1
#   Review: horrivel de acessar
# ------
# Value inserted successfully.
# Review 152:
#   Username: Allen Walker
#   Rating: 1
#   Review: burocrático e disfuncional
# ------
# Value inserted successfully.
# Review 153:
#   Username: Johnny Kellton
#   Rating: 5
#   Review: pratico e acessivel
# ------
# Value inserted successfully.
# Review 154:
#   Username: Divany Batista Alves
#   Rating: 5
#   Review: aplicativo muito bom
# ------
# Value inserted successfully.
# Review 155:
#   Username: Vitória Beatriz
#   Rating: 5
#   Review: very good
# ------
# Value inserted successfully.
# Review 156:
#   Username: Adenilson De Jesus Santos
#   Rating: 5
#   Review: very easy
# ------
# Value inserted successfully.
# Review 157:
#   Username: July Kelly
#   Rating: 5
#   Review: very good
# ------
# Value inserted successfully.
# Review 158:
#   Username: Natália Santos
#   Rating: 5
#   Review: Muito útil!
# ------
# Value inserted successfully.
# Review 159:
#   Username: Guanabara de boné chefe do morro
#   Rating: 3
#   Review: Os serviços não estão unificados no aplicativo, toda hora precisa sair do app para ir para o navegador para fazer qualquer coisa.
# ------
# Value inserted successfully.
# Review 160:
#   Username: vc kpaz
#   Rating: 5
#   Review: 👍 meu nome é Jesus *corretor*⚖️ o _motivo_ do contato☎️ e *facilitar* a🏡 _aquisição🔑_*de* _imovel
# ------
# Value inserted successfully.
# Review 161:
#   Username: Lucas Mendes
#   Rating: 1
#   Review: Esses assalariados que respondem resenhas de aplicativos não ajudam em nada e só sabem dar respostas automáticas, por isso que não evolui na vida.
# ------
# Value inserted successfully.
# Review 162:
#   Username: Diego Vasconcelos
#   Rating: 1
#   Review: Perfeito para facilitar um enfarto. Para usar certas funções, fica abrindo o navegador. Seu uso é muito confuso. Não tem me servido como deveria. Não cumpriu com suas funções.
# ------
# Value inserted successfully.
# Review 163:
#   Username: Mary Lima
#   Rating: 5
#   Review: otimo app
# ------
# Value inserted successfully.
# Review 164:
#   Username: francisco Paulo Aragao
#   Rating: 5
#   Review: muito bom
# ------
# Value inserted successfully.
# Review 165:
#   Username: Erivelton Duarte
#   Rating: 2
#   Review: Não funciona
# ------
# Value inserted successfully.
# Review 166:
#   Username: Genesio Ferreira
#   Rating: 5
#   Review: mas rapido
# ------
# Value inserted successfully.
# Review 167:
#   Username: Douglas Rafael do Amaral
#   Rating: 1
#   Review: Reconhecimento facial não funciona, péssima interface principalmente para idosos, não é intuitivo e tem mtos bugs! Fico me perguntando se são funcionários públicos que o fazem, pois pela péssima qualidade parece que sim...
# ------
# Value inserted successfully.
# Review 168:
#   Username: MMA -AKI
#   Rating: 4
#   Review: bom 😃
# ------
# Value inserted successfully.
# Review 169:
#   Username: John Logan
#   Rating: 1
#   Review: Pra entrar precisa de reconhecimento facial, o que fazer se não tem câmera? Tem opção de número bancário, nem conta no banco eu tenho. No final é só mais um app inútil. Anos depois e continua inútil.
# ------
# Value inserted successfully.
# Review 170:
#   Username: JOSE CARLOS PEREIRA
#   Rating: 5
#   Review: ok
# ------
# Value inserted successfully.
# Review 171:
#   Username: Marcos Lago
#   Rating: 5
#   Review: topster
# ------
# Value inserted successfully.
# Review 172:
#   Username: s w o o s h
#   Rating: 5
#   Review: like it
# ------
# Value inserted successfully.
# Review 173:
#   Username: Denilson Barreto
#   Rating: 5
#   Review: ok
# ------
# Value inserted successfully.
# Review 174:
#   Username: Luiz Carlos Xavier
#   Rating: 5
#   Review: parabens
# ------
# Value inserted successfully.
# Review 175:
#   Username: Joseph kamli Pascal
#   Rating: 5
#   Review: services
# ------
# Value inserted successfully.
# Review 176:
#   Username: Alex
#   Rating: 1
#   Review: Fotografa você pra RECONHECIMENTO FACIAL, e adiciona sua foto no perfil sem opção de remover????? Isso é uso indevido! Quero remoção da foto. Se eu quisesse ter foto em telas por aí, eu mesmo faria isso. Denunciem o APP por uso sem autorização.
# ------
# Value inserted successfully.
# Review 177:
#   Username: Claus Pacheco
#   Rating: 1
#   Review: lixo
# ------
# Value inserted successfully.
# Review 178:
#   Username: Rafael Humberto Tovar Tovar
#   Rating: 5
#   Review: legal
# ------
# Value inserted successfully.
# Review 179:
#   Username: Emanuel Costa
#   Rating: 4
#   Review: bom
# ------
# Value inserted successfully.
# Review 180:
#   Username: glauber da silva
#   Rating: 5
#   Review: bom
# ------
# Value inserted successfully.
# Review 181:
#   Username: rogerio jose
#   Rating: 4
#   Review: tank
# ------
# Value inserted successfully.
# Review 182:
#   Username: Sergio Amorim
#   Rating: 5
#   Review: Ótimo
# ------
# Value inserted successfully.
# Review 183:
#   Username: Lucas Gomes
#   Rating: 3
#   Review: razoável
# ------
# Value inserted successfully.
# Review 184:
#   Username: Cláudio César
#   Rating: 3
#   Review: Aplicativo com problemas para reconhecer a face e pede pra acessar a partir da conta de bancos tradicionais para validar (banco do brasil, caixa, santander, itau...), sendo que nao possuo conta em nenhum deles, só uso NuBank (e nao tem opção de validar com ele).
# ------
# Value inserted successfully.
# Review 185:
#   Username: André Müller
#   Rating: 3
#   Review: O app de forma geral é bom, mas tem uma falha enorme que previne o uso por mim em diversas instâncias: ele pede por um número de celular brasileiro, coisa que não possuo. Então, ou vocês implementam outra maneira pra 2FA, ou permitam números internacionais.
# ------
# Value inserted successfully.
# Review 186:
#   Username: Thiago Simoes
#   Rating: 3
#   Review: aparentemente funciona, mas quando vc realmente precisa falha... Estou há dois dias tentando lugar no app da Carteira Digital, que me manda para o portal gov.br. Eu coloco usuario e senha, clico em "Entrar" e nada acontece. Nem erro, nem sucesso, absolutamente nada. Nada confiável.
# ------
# Value inserted successfully.
# Review 187:
#   Username: Kleber Contini
#   Rating: 1
#   Review: 1. Não possui login próprio e direciona para o website ou seja, e só um LINK dentro de um app; 2. Não reconhece meu rosto e a outra única opção é compartilhar meus dados bancários(pegaram pesado hein); 3. Não te dá uma outra opção; 4. Acredito que se desacatarmos o aplicativo seremos presos.
# ------
# Value inserted successfully.
# Review 188:
#   Username: Alessandra V.
#   Rating: 2
#   Review: reconhecimento facial não funciona e link com app Itaú tb não. então não consigo fazer o cadastro
# ------
# Value inserted successfully.
# Review 189:
#   Username: Jonathan
#   Rating: 5
#   Review: Uma das melhores criações do Governo Bolsonaro, parabéns por facilitarem a vida do cidadão!
# ------
# Value inserted successfully.
# Review 190:
#   Username: Fabio Almeida
#   Rating: 5
#   Review: Excelente programa do governo. Agora o brasileiro pode ter sua assinatura digital grátis.
# ------
# Value inserted successfully.
# Review 191:
#   Username: Adriane Santos
#   Rating: 1
#   Review: O que dizer!? Não funciona e te faz perder seu tempo.
# ------
# Value inserted successfully.
# Review 192:
#   Username: Daniel Silva de Assuncao
#   Rating: 5
#   Review: Sempre top 🎩 5 estrelas
# ------
# Value inserted successfully.
# Review 193:
#   Username: Thalison Alexander
#   Rating: 1
#   Review: Horrível! Lento e ainda não funciona o reconhecimento facial e é único aplicativo que isso acontece comigo!
# ------
# Value inserted successfully.
# Review 194:
#   Username: Fran Ramos
#   Rating: 1
#   Review: parece spam o site
# ------
# Value inserted successfully.
# Review 195:
#   Username: Jardel Morais
#   Rating: 1
#   Review: Hoje nao enviou sms nem com reza braba e ai nao tem como acessar, inviavel assim. O app nao enviou nenhuma notificacao, nao consigo acessar
# ------
# Value inserted successfully.
# Review 196:
#   Username: José Soares
#   Rating: 5
#   Review: good
# ------
# Value inserted successfully.
# Review 197:
#   Username: Emanuelle Duarte
#   Rating: 3
#   Review: testando por enquanto
# ------
# Value inserted successfully.
# Review 198:
#   Username: Lucas Alphaville
#   Rating: 5
#   Review: perfeitamente e seguro
# ------
# Value inserted successfully.
# Review 199:
#   Username: Luciano Ramos Katzenstein
#   Rating: 5
#   Review: Excelente. Obrigado Governo Federal pela iniciativa de integração de todos os Bancos de Dados. Graças ao Gov do período de 2019 a 2022 obtivemos melhorias visando economia de recurso e melhor qualidade de serviços ao contribuinte
# ------
# Value inserted successfully.
# Review 200:
#   Username: werber bezerra
#   Rating: 5
#   Review: excelente legado
# ------
# Value inserted successfully.
# Review 201:
#   Username: Bianca 03
#   Rating: 1
#   Review: experiência horrível, terrível, lamentável, vexaminosa. Saí na foto com cara de maluca de tanta raiva que eu passei tentando fazer o app entender que meu rosto é de um ser humano. Estou mentalmente abalada.
# ------
# Value inserted successfully.
# Review 202:
#   Username: Kalina Sedano
#   Rating: 5
#   Review: Bom
# ------
# Value inserted successfully.
# Review 203:
#   Username: Jeezyel Pereira
#   Rating: 5
#   Review: rop
# ------
# Value inserted successfully.
# Review 204:
#   Username: Mundo Impossível
#   Rating: 5
#   Review: bom
# ------
# Value inserted successfully.
# Review 205:
#   Username: Mr champagne papi
#   Rating: 5
#   Review: Bueno
# ------
# Value inserted successfully.
# Review 206:
#   Username: Ed Records Campinas
#   Rating: 4
#   Review: bom
# ------
# Value inserted successfully.
# Review 207:
#   Username: Faber Velloso
#   Rating: 1
#   Review: Eu sigo recebendo a msg "reconhecimento facial não realizado" sempre que faço o login (já tenho a conta gov.br). Sendo que nem aparece a opção de reconhecimento facial, eu simplesmente clico no login, coloco os dados e recebo esta msg
# ------
# Value inserted successfully.
# Review 208:
#   Username: Augusto Gomes
#   Rating: 1
#   Review: Impossível fazer reconhecimento fácil, sempre da erro. Não consigo logar no app por causa disso.
# ------
# Value inserted successfully.
# Review 209:
#   Username: ENDREW SANTOS
#   Rating: 1
#   Review: muito ruim, lento, mal desenvolvido, servidor ruim. Simplusmente horrível!
# ------
# Value inserted successfully.
# Review 210:
#   Username: Gleydson Góes
#   Rating: 5
#   Review: App obrigatório para todo cidadão brasileiro!
# ------
# Value inserted successfully.
# Review 211:
#   Username: milfanitus 3001
#   Rating: 1
#   Review: m.erd.@
# ------
# Value inserted successfully.
# Review 212:
#   Username: Michele Morais
#   Rating: 2
#   Review: muito complicado
# ------
# Value inserted successfully.
# Review 213:
#   Username: Yuri Possimozer
#   Rating: 5
#   Review: Adicionem a possibilidade de salvar os documentos da aba "Carteira de documentos" do aplicativo de vocês no Google Wallet (Carteira do Google)! Da mesma forma como já ocorre no aplicativo Conecte SUS com o Certificado de Vacinação e o Cartão do SUS! 😁🤩
# ------
# Value inserted successfully.
# Review 214:
#   Username: Gustavo Mattos Bottega
#   Rating: 2
#   Review: Quando troquei de celular, para o meu primeiro login pediu reconhecimento facial e não reconhecia de jeito nenhum, e não tinha outra alternativa para logar. Depois de um bom tempo consegui fazer o reconhecimento, mas fiquei sem poder usar o app.
# ------
# Value inserted successfully.
# Review 215:
#   Username: João Daniel Tronco Mandel
#   Rating: 1
#   Review: App ridículo, pra variar tudo que vem do governo não funciona, desde a última atualização o app não abre mais e exige reconhecimento facial que quando não faz o app nunca reconhece ou sempre dá tempo esgotado e vc fica na mão o que é o costume com todos os apps que vem do governo. Só dou 1 estrela por que não posso deixar sem nenhuma.
# ------
# Value inserted successfully.
# Review 216:
#   Username: Michelle Torres
#   Rating: 1
#   Review: O reconhecimento facial não funciona mesmo com o fundo branco e a luz do ducking dia
# ------
# Value inserted successfully.
# Review 217:
#   Username: Natan Kayevo
#   Rating: 1
#   Review: Péssimo do começo ao fim
# ------
# Value inserted successfully.
# Review 218:
#   Username: Teibokujin
#   Rating: 1
#   Review: IMPOSSÍVEL concluir o reconhecimento facial
# ------
# Value inserted successfully.
# Review 219:
#   Username: José Dias
#   Rating: 5
#   Review: Que ideia genial de juntar todos os documentos em um único. Parabéns.
# ------
# Value inserted successfully.
# Review 220:
#   Username: Daisy Pimentel
#   Rating: 1
#   Review: Não penso ser "saudavel" compartilhar os dados da conta bancaria.
# ------
# Value inserted successfully.
# Review 221:
#   Username: Lucas Martins Mendes
#   Rating: 4
#   Review: provavelmente poderia ter login sem necessidade de browser externo, mas em geral funciona ok
# ------
# Value inserted successfully.
# Review 222:
#   Username: Matheus Jansen
#   Rating: 1
#   Review: Quando coloco pra aumentar a segurança da conta o aplicativo simplesmente nao carrega
# ------
# Value inserted successfully.
# Review 223:
#   Username: Willian Lira
#   Rating: 1
#   Review: Bem ruim, como todo o resto
# ------
# Value inserted successfully.
# Review 224:
#   Username: Juana Gonzalez
#   Rating: 1
#   Review: nao recebi o codigo de autorizacao enviado ao celular
# ------
# Value inserted successfully.
# Review 225:
#   Username: Steffany Silva
#   Rating: 2
#   Review: muito ruim, no reconhecimento facial demora muito. podia ser mais rápido
# ------
# Value inserted successfully.
# Review 226:
#   Username: Sebastião carvalho
#   Rating: 3
#   Review: Ficou muito ruim o acesso
# ------
# Value inserted successfully.
# Review 227:
#   Username: Thiago Soares
#   Rating: 1
#   Review: Sistema muito ruim. Funciona raramente e dá muito erro.
# ------
# Value inserted successfully.
# Review 228:
#   Username: Nonato Junior
#   Rating: 4
#   Review: Tá melhorando bastante a cada atualização. Parabéns.
# ------
# Value inserted successfully.
# Review 229:
#   Username: Pollyana Faria
#   Rating: 1
#   Review: Nunca consigo fazer o reconhecimento facial.
# ------
# Value inserted successfully.
# Review 230:
#   Username: Everton Carlos Harthe
#   Rating: 1
#   Review: não tem opção de criar conta nova
# ------
# Value inserted successfully.
# Review 231:
#   Username: Rangel Alcides
#   Rating: 1
#   Review: pior site que ja vi na minha vida, os desenvolvedores sairam do lixo
# ------
# Value inserted successfully.
# Review 232:
#   Username: Lucas Hiroyuki
#   Rating: 1
#   Review: não consegui evoluir meu cadastro pra prata de jeito nenhum
# ------
# Value inserted successfully.
# Review 233:
#   Username: Dinora Valentim
#   Rating: 1
#   Review: Muito dificil de cadastrar. Muito ruim.
# ------
# Value inserted successfully.
# Review 234:
#   Username: Nanda Amaral
#   Rating: 1
#   Review: App terrivel muito mal otimizado, igualzinho o site um lixo
# ------
# Value inserted successfully.
# Review 235:
#   Username: João Pedro
#   Rating: 1
#   Review: O reconhecimento facial simplesmente não identifica meu rosto
# ------
# Value inserted successfully.
# Review 236:
#   Username: Sandra Ribeiro
#   Rating: 1
#   Review: Reconhecimento só serve para dar dor de cabeça.
# ------
# Value inserted successfully.
# Review 237:
#   Username: Thiago Rafael
#   Rating: 1
#   Review: Péssimo, horrível, tecnologia nota 0, é um parto para conseguir realizar as validações que pedem, péssimo mesmo!
# ------
# Value inserted successfully.
# Review 238:
#   Username: Zamucx _
#   Rating: 1
#   Review: horrível, cheio de bugs e difícilmente funciona
# ------
# Value inserted successfully.
# Review 239:
#   Username: Bruno Monteiro
#   Rating: 3
#   Review: serviço ok, deveria explicar melhor os processos
# ------
# Value inserted successfully.
# Review 240:
#   Username: Samuel araujo leite
#   Rating: 1
#   Review: O reconhecimento facial não funciona, sempre mostra a mensagem que o meu rosto não foi encontrado.
# ------
# Value inserted successfully.
# Review 241:
#   Username: Antonio Jr
#   Rating: 5
#   Review: excellent app
# ------
# Value inserted successfully.
# Review 242:
#   Username: Marcelo Dixon
#   Rating: 5
#   Review: perfect.
# ------
# Value inserted successfully.
# Review 243:
#   Username: Leonardo Gazola
#   Rating: 1
#   Review: pede informação até da hora que seu cachorro faz necessidades. deveria ser mais simples prático e menos invasivo
# ------
# Value inserted successfully.
# Review 244:
#   Username: Sítio Cotiara
#   Rating: 1
#   Review: É impossível fazer o reconhecimento facial. Só queria fazer o rnpc, mas não vou fornecer minha senha do banco
# ------
# Value inserted successfully.
# Review 245:
#   Username: Kahena
#   Rating: 2
#   Review: Não reconhece o rosto nunca! Tô tentando subir o nível da conta mas nunca reconhece o meu rosto, não importa onde eu esteja, com iluminação,sem maquiagem , não reconhece!
# ------
# Value inserted successfully.
# Review 246:
#   Username: Modulo car
#   Rating: 5
#   Review: the best
# ------
# Value inserted successfully.
# Review 247:
#   Username: Bryan soyer
#   Rating: 5
#   Review: good
# ------
# Value inserted successfully.
# Review 248:
#   Username: Safeer Brazil
#   Rating: 5
#   Review: good
# ------
# Value inserted successfully.
# Review 249:
#   Username: Gabriel Rabelo
#   Rating: 1
#   Review: Leitura facial não funciona
# ------
# Value inserted successfully.
# Review 250:
#   Username: M
#   Rating: 1
#   Review: Identificação facial não funciona
# ------
# Value inserted successfully.
# Review 251:
#   Username: R.Medeiros
#   Rating: 5
#   Review: eficiente e prático
# ------
# Value inserted successfully.
# Review 252:
#   Username: filipi inokov
#   Rating: 5
#   Review: Fácil de usar
# ------
# Value inserted successfully.
# Review 253:
#   Username: giovani oliveira
#   Rating: 5
#   Review: very good
# ------
# Value inserted successfully.
# Review 254:
#   Username: SHISHPAL Singh
#   Rating: 5
#   Review: Good
# ------
# Value inserted successfully.
# Review 255:
#   Username: Yuri Miguel Guimarães
#   Rating: 5
#   Review: great
# ------
# Value inserted successfully.
# Review 256:
#   Username: Julius Caesar Brutomantes
#   Rating: 1
#   Review: App péssimo.
# ------
# Value inserted successfully.
# Review 257:
#   Username: Diogo Olliver
#   Rating: 1
#   Review: erro 403.
# ------
# Value inserted successfully.
# Review 258:
#   Username: Fernando Alves
#   Rating: 1
#   Review: Minha senha do nada parou de funcionar. Quando coloco para recuperar minha senha sou redirecionando para uma página inexistente após fazer meu reconhecimento facial:(
# ------
# Value inserted successfully.
# Review 259:
#   Username: Joabel Barbieri
#   Rating: 1
#   Review: Totalmente Inútil para quem mora fora do país. Não aceita endereço no exterior e não aceita celular de fora. Só mostra que não pensam nos mais de 5 milhões de brasileiros que vivem e trabalham no exterior
# ------
# Value inserted successfully.
# Review 260:
#   Username: Omaima Salem
#   Rating: 5
#   Review: its 👍
# ------
# Value inserted successfully.
# Review 261:
#   Username: Marco Conforto
#   Rating: 5
#   Review: Muito prático
# ------
# Value inserted successfully.
# Review 262:
#   Username: Elo vanderbijl
#   Rating: 1
#   Review: Muito ruim este aplicativo tendo este modelo se reconhecimento facial e níveis ( ouro, prata e bronze) estou tendo o maior aborrecimento somente para agendar uma hora na embaixada brasileira. Péssimo!!!!
# ------
# Value inserted successfully.
# Review 263:
#   Username: Sleeping Panda
#   Rating: 1
#   Review: Horrivel
# ------
# Value inserted successfully.
# Review 264:
#   Username: Rafa Silva
#   Rating: 5
#   Review: eccelent
# ------
# Value inserted successfully.
# Review 265:
#   Username: Bruno de Moraes
#   Rating: 5
#   Review: Ok.
# ------
# Value inserted successfully.
# Review 266:
#   Username: Karina Brito
#   Rating: 1
#   Review: Não consigo logar! Fala que o captcha está incorreto, mas não aparece nenhum!! Acabei de recuperar a senha, trocar e fazet o reconhecimento facial e, quando vou logar no app, diz "senha incorreta". 😤😡😮‍💨
# ------
# Value inserted successfully.
# Review 267:
#   Username: Alexandre Thomaz (YOLAWS)
#   Rating: 5
#   Review: 🔥
# ------
# Value inserted successfully.
# Review 268:
#   Username: Tadeu Araujo
#   Rating: 1
#   Review: Tão mal feito que ao fazer o login pede para baixar o app, fora que o reconhecimento facil não funciona, e nem da a opção de recadastrar ou usar outra forma de validação. Simplesmente inútil.
# ------
# Value inserted successfully.
# Review 269:
#   Username: Marco SANTILLI
#   Rating: 1
#   Review: Demorou 30 minutos para fazer reconhecimento facial. Tive que trocar de ambiente varias vezes aqui em casa e mesmo assim não teve êxito. Por algum milagre, na última tentativa, reconheceu.
# ------
# Value inserted successfully.
# Review 270:
#   Username: Rael Leandr
#   Rating: 5
#   Review: ok
# ------
# Value inserted successfully.
# Review 271:
#   Username: CarliN
#   Rating: 5
#   Review: prático
# ------
# Value inserted successfully.
# Review 272:
#   Username: Sheyla Montoya
#   Rating: 5
#   Review: legal
# ------
# Value inserted successfully.
# Review 273:
#   Username: Leandro Trepte
#   Rating: 5
#   Review: ótimo
# ------
# Value inserted successfully.
# Review 274:
#   Username: Arthur Guerra
#   Rating: 1
#   Review: desgraça
# ------
# Value inserted successfully.
# Review 275:
#   Username: Clarissa Vianna
#   Rating: 2
#   Review: Aplicativo agora pede reconhecimento facial e não abre mais colocando apenas a senha? E como fazer pra acessar a conta de minha irmã incapaz, da qual sou curadora??? Lamentável que não aponte outros caminhos na própria tela.
# ------
# Value inserted successfully.
# Review 276:
#   Username: daniel ueda
#   Rating: 3
#   Review: Após problemas com autenticação biométrica (foto do rosto) e fatores de autenticação (banco e telefone), está funcionando. Por agregar vários serviços de órgãos diferentes, a navegação ainda pode melhorar, mas parece que as equipes estão trabalhando nisso.
# ------
# Value inserted successfully.
# Review 277:
#   Username: FT Oyama
#   Rating: 1
# ...
# ------
# Value inserted successfully.
# Review 200:
#   Username: A Google user
#   Rating: 1
#   Review: só dá erro pra mim ao buscar os benefícios. nao sei se é só pra mim.
# ------
# Value inserted successfully.
# Review 201:
#   Username: A Google user
#   Rating: 1
#   Review: Não faz a troca de senha - eu coloquei todas as características solicitadas, não sou burrinha....
# ------
# Value inserted successfully.
# Review 202:
#   Username: A Google user
#   Rating: 5
#   Review: prático
# ------
# Value inserted successfully.
# Review 203:
#   Username: A Google user
#   Rating: 5
#   Review: Muito prático! É possivel cobsegur as mesmas informações sem a necessidade de visitar uma agência do INSS
# ------
# Value inserted successfully.
# Review 204:
#   Username: A Google user
#   Rating: 1
#   Review: N posso avaliar. ele instala mas n abre
# ------
# Value inserted successfully.
# Review 205:
#   Username: A Google user
#   Rating: 1
#   Review: pessima navegacao nada amigavel
# ------
# Value inserted successfully.
# Review 206:
#   Username: A Google user
#   Rating: 1
#   Review: Nao cagastra da erro
# ------
# Value inserted successfully.
# Review 207:
#   Username: A Google user
#   Rating: 1
#   Review: nada funciona
# ------
# Value inserted successfully.
# Review 208:
#   Username: A Google user
#   Rating: 1
#   Review: Muito mal feito! Quando se tenta cadasttar no servico, sempre dá um erro que te faz retornar ao início da operacao. Este app está a altura dos servidores preguiçosos do funcionalismo publico.
# ------
# Value inserted successfully.
# Review 209:
#   Username: A Google user
#   Rating: 1
#   Review: É a primeira vez que sinto necessidade de usar o aplicativo, para acessar meu extrato previdenciário. E estou totalmente decepcionado com a falta de qualidade do aplicativo, não é possível realizar Cadastro pois quando se pede para efetuar login e você clica em se cadastrar, nada acontece. Não é minha primeira decepção com a qualidade de serviços ofertados pelo INSS, uma pena.
# ------
# Value inserted successfully.
# Review 210:
#   Username: A Google user
#   Rating: 3
#   Review: Lento mas muito bom. De vez em quando trava. Mas eu gosto. Demora entrar.
# ------
# Value inserted successfully.
# Review 211:
#   Username: A Google user
#   Rating: 5
#   Review: Estava dando erro, "divergência de dados cadastrais", descobri que a senha estava errada. Deveriam corrigir, as pessoas acham que são outros dados e negativam o app, como foi meu caso. Agora que vi que está ok, dei 5 estrelas. Vlw
# ------
# Value inserted successfully.
# Review 212:
#   Username: A Google user
#   Rating: 1
#   Review: Não funciona! Não conecta! Não castrada! Uma mrd!
# ------
# Value inserted successfully.
# Review 213:
#   Username: A Google user
#   Rating: 1
#   Review: O app simplesmente parou de funcionar, fica numa tela branca.
# ------
# Value inserted successfully.
# Review 214:
#   Username: A Google user
#   Rating: 1
#   Review: Não consigo nem fazer o cadastro. A página ja da erro
# ------
# Value inserted successfully.
# Review 215:
#   Username: A Google user
#   Rating: 5
#   Review: Aplicativo bem funcional! Consegui ter acesso as minhas contribuições e aos
# meus benefícios. Ótima iniciativa!
# ------
# Value inserted successfully.
# Review 216:
#   Username: A Google user
#   Rating: 3
#   Review: Comsegui me cadastrar, mas tento cadastrar minha mãe para que ela veja o
# dela e da erro de informações depois de todas as perguntas, tentei depois
# de 24h e as informações ainda nao coincidem!!!!
# ------
# Value inserted successfully.
# Review 217:
#   Username: A Google user
#   Rating: 5
#   Review: O app está funcionando muito bem, não tive problemas até agora, fácil de
# usar, consegui atualizar todos os meus dados, endereço, telefone, e-mail,
# etc.
# ------
# Value inserted successfully.
# Review 218:
#   Username: A Google user
#   Rating: 1
#   Review: O "Meu INSS" não está funcionando nem pelo App, nem pelo site. Faço o
# cadastro e depois não sai da tela de dar autorização para utilizar o CPF,
# NIT e Nome completo. Já tentei pelo IE11, Edge, Firefox, Chrome, Android e
# IOS. Em todos o mesmo problema.
# ------
# Value inserted successfully.
# Review 219:
#   Username: A Google user
#   Rating: 1
#   Review: Mas que lixo de app é este? É surpreendente como o Governo só presta para
# nos tomar dinheiro e não tem competência nem para criar um aplicativo útil.
# Eu queria apenas verificar me Cnis e não dá n para digitar meu próprio nome.
# ------
# Value inserted successfully.
# Review 220:
#   Username: A Google user
#   Rating: 1
#   Review: A tela fica branca e não consigo acessar o aplicativo. No site, os servidores do inss não respeitam nem um pouco o prazo do processo. Meu processo estava datado para finalizar em 11 de junho e apenas em 14 de agosto tive a resposta. Nem no site, nem no app mostra minha carta, nem mostra quando tento alterar ou ver como estão meus dados cadastrais.
# ------
# Value inserted successfully.
# Review 221:
#   Username: A Google user
#   Rating: 2
#   Review: Não consigo me cadastrar. Dá o seguinte erro: Erro geral do sistema.Contate
# o suporte técnico. Código do erro 05C8DBC7FD
# ------
# Value inserted successfully.
# Review 222:
#   Username: A Google user
#   Rating: 1
#   Review: Nao funciona o extrato csi. Ja tentei inúmeras vezes. Apresenta erro e fala para tentar mais tarde
# ------
# Value inserted successfully.
# Review 223:
#   Username: A Google user
#   Rating: 1
#   Review: Impossível obter o Extrato Previdenciário CNIS (ocorreu um erro em sua
# requisição, por favor tente mais tarde)
# ------
# Value inserted successfully.
# Review 224:
#   Username: A Google user
#   Rating: 1
#   Review: Antes da instabilidade o campo do cpf recebia os numeros todo trocado,
# agora nem preenche o campo de cpf e senha qdo digita.
# ------
# Value inserted successfully.
# Review 225:
#   Username: A Google user
#   Rating: 2
#   Review: Há dias tentando gerar o extrato Previdenciário (CNIS), mas sem sucesso.
# Sempre apresenta uma mensagem de "Ocorreu um erro na sua requisição. Tente
# novamente mais tarde". Isso ocorre tanto no app quanto em páginas web. Há
# alguma previsão de melhoria??
# ------
# Value inserted successfully.
# Review 226:
#   Username: A Google user
#   Rating: 4
#   Review: Ótima iniciativa! No momento não está abrindo, mas estou certo de que vocês estão trabalhando para corrigir isso. Funciona dessa forma mesmo! É preciso colocar em funcionamento, monitorar as falhas e corrigi-las. Desejo sucesso à DATAPREV!
# ------
# Value inserted successfully.
# Review 227:
#   Username: A Google user
#   Rating: 1
#   Review: App  nao funciona. Moro no exterior e Nao consigo fazer o casastro no meu celular
# ------
# Value inserted successfully.
# Review 228:
#   Username: A Google user
#   Rating: 1
#   Review: Erro, erro, erro, erro, só isso que esse aplicativo fornece.
# ------
# Value inserted successfully.
# Review 229:
#   Username: A Google user
#   Rating: 3
#   Review: Funcionou alguns topicos, Como extrato de pgto, CNIS . porem IR nao gerou nem consulta de beneficio apareceu Nada.
# ------
# Value inserted successfully.
# Review 230:
#   Username: A Google user
#   Rating: 1
#   Review: Sempre que tento acessar recebo a mensagem que "o serviço de autenticação de usuário está indisponível." Não consegui acessar nenhuma vez.
# ------
# Value inserted successfully.
# Review 231:
#   Username: A Google user
#   Rating: 1
#   Review: Não consigo acessar o meu cadastro, eu sempre recebo o erro que o serviço de autenticação do usuário está indisponível no momento!
# ------
# Value inserted successfully.
# Review 232:
#   Username: A Google user
#   Rating: 1
#   Review: App nao funciona! Campo para inserir numero de cpf não aceita a numeração completa! Impossível utilizar....detalhe....não é somente hoje ok? App sem função!!!!
# ------
# Value inserted successfully.
# Review 233:
#   Username: A Google user
#   Rating: 1
#   Review: Qual ė o endereco de E-mail do desenvolvedor????  Faz mais de 11 meses que eu tento entrar e só consegui 1 vez; sempre dá uma desculpa esfarrapada tipo "o serviço de autenticação do usuário está indisponível no momento, tente mais tarde" E na única vez que eu consegui entrar , na aba do histórico de créditos , não consegui tirar nenhuma informação . Que vergonha!!!
# ------
# Value inserted successfully.
# Review 234:
#   Username: A Google user
#   Rating: 5
#   Review: Muito bom, parabéns pelo aplicativo
# ------
# Value inserted successfully.
# Review 235:
#   Username: A Google user
#   Rating: 1
#   Review: App nem me deixa me cadastrar. Dá erro nos dados preenchidos. Já fiz várias vezes. App não funciona.
# ------
# Value inserted successfully.
# Review 236:
#   Username: A Google user
#   Rating: 1
#   Review: seu apk esta muito desatualizado com as informações dos usuarios do inss onde ja se viu fazer um cadastro que existe divergencias sendo que nao existe pessoa que saiba mais sobre mim do que eu mesmo obrigado
# ------
# Value inserted successfully.
# Review 237:
#   Username: A Google user
#   Rating: 2
#   Review: Terrível. Cadastramento sofrível e constantemente fora do ar, informações incompletas, dificuldades com o layout e o sistema de CAPTCHA, que por sinal é solicitado a cada ação realizada.  Realmente terrível.  --  O produtor sugeriu realizar o cadastro na agência INSS, devido a instabilidade do sistema.  Meu caro, isso é exatamente o que a tecnologia deveria evitar.
# ------
# Value inserted successfully.
# Review 238:
#   Username: A Google user
#   Rating: 5
#   Review: App muito bom e prático. Gostei bastante.
# ------
# Value inserted successfully.
# Review 239:
#   Username: A Google user
#   Rating: 1
#   Review: péssimo!! não ajuda se precisa de um cadasteo prévio em uma. agência. 💩
# ------
# Value inserted successfully.
# Review 240:
#   Username: Maurilio Dias
#   Rating: 1
#   Review: Não consigo recuperar senha, pois este app simplesmente não funciona!
# ------
# Value inserted successfully.
# Review 241:
#   Username: A Google user
#   Rating: 1
#   Review: Pior App, exatamente como tentar atendimento telefônico.... impossível
# ------
# Value inserted successfully.
# Review 242:
#   Username: A Google user
#   Rating: 1
#   Review: Não consigo criar minha conta de maneira nenhuma
# ------
# Value inserted successfully.
# Review 243:
#   Username: Nielly Dj Playlists Qmusic
#   Rating: 1
#   Review: Não nunca consigo usar. App muito ruim
# ------
# Value inserted successfully.
# Review 244:
#   Username: Daniel Colas
#   Rating: 4
#   Review: Falha ocasional na parte de simulação de aposentadoria.
# ------
# Value inserted successfully.
# Review 245:
#   Username: Kedma Menezes
#   Rating: 5
#   Review: Faço tudo nele. Muito bom.
# ------
# Value inserted successfully.
# Review 246:
#   Username: A Google user
#   Rating: 1
#   Review: Ficou horrível, após a atualização.. o app nao abre de maneira nenhuma sempre da quebra de link
# ------
# Value inserted successfully.
# Review 247:
#   Username: A Google user
#   Rating: 1
#   Review: Horrível, não consigo cadastrar e isso está acontecendo em todo lugar, seja aplicativo, seja site. Mando email e não recebo resposta. Horrível!!!
# ------
# Value inserted successfully.
# Review 248:
#   Username: Cinthia Faria Lima
#   Rating: 1
#   Review: Entramos com pedido de pensão por falecimento, através do app, agora diz que não existe solicitação.
# ------
# Value inserted successfully.
# Review 249:
#   Username: Igor Reis
#   Rating: 1
#   Review: Não tem um serviço que funciona. Cada solicitação demora uma eternidade para para, no final, emitir um erro.
# ------
# Value inserted successfully.
# Review 250:
#   Username: Erica Ura
#   Rating: 1
#   Review: Não consegui o que queria. Nem precisava ter baixado, pois me redirecionou para o site do INSS.
# ------
# Value inserted successfully.
# Review 251:
#   Username: A Google user
#   Rating: 1
#   Review: app nao funciona pessimo
# ------
# Value inserted successfully.
# Review 252:
#   Username: A Google user
#   Rating: 1
#   Review: O zoom FICA encima do "entrar,"dpois das placas não conecta e repete TD do
# inicio.tinha q ser do governor brasileiro
# ------
# Value inserted successfully.
# Review 253:
#   Username: Garcia Jero
#   Rating: 5
#   Review: muito bom serviço
# ------
# Value inserted successfully.
# Review 254:
#   Username: A Google user
#   Rating: 2
#   Review: Problema no campo de CEP. Ao digitar o CEP nas informações de cadastro, ele automaticamente apaga um número e informa que precisa de um cep valido, impossibilitando a atualização de todo o cadastro.
# ------
# Value inserted successfully.
# Review 255:
#   Username: Dea VC
#   Rating: 1
#   Review: Não consigo acessar bloqueio/desbloqueio de empréstimo. Roda e nao aparece nada. Mensagem: " Aguardando serviços " não sai dessa tela.
# ------
# Value inserted successfully.
# Review 256:
#   Username: Andre Carlucci
#   Rating: 1
#   Review: Não tenho celular no Brasil e o app não me permite entrar sem um número. Como cidadão Brasileiro, gostaria de ter acesso à minha aposentadoria.
# ------
# Value inserted successfully.
# Review 257:
#   Username: Erismar Lima
#   Rating: 1
#   Review: Olá prezados desenvolvedores...após logar sempre acorre erro ao tentar acessar outros links ... Após login . Podem me ajudar ? Estou acessando fora do Brasil . Obrigado
# ------
# Value inserted successfully.
# Review 258:
#   Username: Lucas Cadenazzi America
#   Rating: 1
#   Review: Not working.
# ------
# Value inserted successfully.
# Review 259:
#   Username: A Google user
#   Rating: 3
#   Review: Vou tentar experiência
# ------
# Value inserted successfully.
# Review 260:
#   Username: A Google user
#   Rating: 1
#   Review: app lixo
# ------
# Value inserted successfully.
# Review 261:
#   Username: ilson Aparecido Silva
#   Rating: 4
#   Review: Exelente.
# ------
# Value inserted successfully.
# Review 262:
#   Username: Sylvio Neto
#   Rating: 1
#   Review: Estou com problemas técnicos com o site, notei que uma api retorna um erro e não aparece na tela do app e nem no site, deixando o usuário sem saber o que aconteceu. Como posso reportar este bug?
# ------
# Value inserted successfully.
# Review 263:
#   Username: Jose Ferreira
#   Rating: 1
#   Review: Esse mês de janeiro o salário mínimo sendo R$1302, a dataprev registrou minha contribuição no sistema como R$1301,99. Faltando 1 centavo. Espero que isso não dê problemas futuros.
# ------
# Value inserted successfully.
# Review 264:
#   Username: Victormateus Szynwelski
#   Rating: 1
#   Review: Quebrado
# ------
# Value inserted successfully.
# Review 265:
#   Username: Anderson Gabriel (Gabriel)
#   Rating: 5
#   Review: Ótimo
# ------
# Value inserted successfully.
# Review 266:
#   Username: RM
#   Rating: 1
#   Review: Eu não tenho CNH pra fazer o Reconhecimento facial. Eu e muitas pessoas não tem CNH. Por favor arrumem esse App, para dar mais opções de Documentos tipo: Titulo de eleitor, CPF, etc, mas apenas com CNH não dá, isso e injusto, não é todo mundo que tem carro nesse e CNH nesse pais não. Por favor arrumem esse App
# ------
# Value inserted successfully.
# Review 267:
#   Username: Su Elipa
#   Rating: 1
#   Review: Meo Deos......estou tentando entrar no site desde o começo do ano 2023 e nao consigo....da mensagem de erro...estou no Canada e é impossivel o contato...nao sei o que se passa....preciso saber o porque minha aposentadoria do acordo internacional de Dezembro ainda nao foi depositada....
# ------
# Value inserted successfully.
# Review 268:
#   Username: Sophia
#   Rating: 1
#   Review: entrei para ver se conseguia fazer minha inscrição no INSS já que pelo site não conseguia e foi a mesma coisa que nada, os campos para inscrição não funcionam adequadamente como o campo de estado civil não tem as opções de "solteira" ou "casada" precisa pesquisar um desses e ainda assim não encontra, por favor resolvam isso pois preciso fazer minha carteira de trabalho.
# ------
# Value inserted successfully.
# Review 269:
#   Username: Guilherme Taffarel Bergamin
#   Rating: 1
#   Review: O aplicativo tem aproximadamente 0 funcionalidades. Edit: entendo. O que eu quis dizer é que não possui qualquer funcionalidade outra que apenas mostrar os dados pessoais. Minha mãe precisa conferir dados sobre a aposentadoria dela, mas não tem nada no app. Ele na prática não possui funcionalidades. Não entendi o propósito do app. A propósito, não é possível copiar o link que passaste na resposta. Talvez seja interessante criar um link mais curto que redireciona para este para facilitar
# ------
# Value inserted successfully.
